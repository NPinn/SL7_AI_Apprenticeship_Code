# %% [markdown]
# # Power, Product and Quotient Rules
#
# This notebook provides:
#
# * Exercises to practice differentiation of simple single variable functions using the power, product and quotient rules.

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %% [markdown]
# ## Exercise 1: power rule practice
#
# * By hand, find the derivative of $f(x) = 4x^{10} - 3x^{-2} + x + 6$.
# * Check your answer using `sympy`.

# %% [markdown]
# ## Exercise 2: power rule or product rule?
#
# This exercise compares two methods for differentiating a product of polynomial functions.
#
# $$f(x) = (2x + 1)(3x + 4)$$
#
# * By hand, find the derivative of $f(x)$ using the product rule.
# * By hand, find the derivative of $f(x)$ by expanding and using the power rule on the terms.
# * Check your answer using `sympy`.

# %% [markdown]
# ## Exercise 3: all together
#
# * By hand, find the derivative of $f(x) = -2 \sin(x) + 3x \cos(x) - \frac{5e^x}{x} $. (Hint: you may be able to combine terms to simplify the equation).
# * Check your answer using `sympy`.
